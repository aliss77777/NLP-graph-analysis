# %% [markdown]
# # Init

# %%
import pandas as pd
import numpy as np
import sidetable 
import os

np.random.seed(67)

# %% [raw]
# Function to return top # of terms per desired segment

# %%
def top_terms_per_segment(summary_table, segment, top_n):
    list_of_segments = np.unique(summary_table[segment])
    top_terms = []
    
    for group in list_of_segments:
        filtered_table = summary_table[summary_table[segment] == group].sort_values('count', ascending = False)
        most_frequent_terms = pd.Series(filtered_table.Label.values)
        most_frequent_terms.drop_duplicates(inplace = True)
        #print(most_frequent_terms[0:top_n])
        most_frequent_terms = most_frequent_terms[0:top_n] 
        most_frequent_terms.reset_index(inplace=True, drop=True)
        top_terms.append(most_frequent_terms)
        
    table_out = pd.DataFrame(top_terms).transpose()
    table_out.columns = list_of_segments
    
    return table_out

# %% [markdown]
# ## Load files

# %% [raw]
# original data file

# %%
data = pd.read_csv('data_backup.csv')

# %% [raw]
# gephi export

# %%
gephi_export = pd.read_csv('gephi export with modularity class.csv')

# %% [raw]
# adjacency list

# %%
adj_list_with_community_label = pd.read_csv('adjacency_list_for_merging.csv')

# %% [markdown]
# # Append Community Labels and summarize

# %% [markdown]
# ## Append labels

# %%
adj_list_with_community_label.rename(columns={'Target':'Label'}, inplace=True)

# %%
adj_list_with_community_label = adj_list_with_community_label.merge(gephi_export, how = 'left', on='Label')

# %%
adj_list_with_community_label
# Out:
#                         id      Label          brand         Id  timeset  \
# 0      1500215577817886725         20  @GlobalGiving         20      NaN
# 1      1500215577817886725   critical  @GlobalGiving   critical      NaN
# 2      1500215577817886725     donate  @GlobalGiving     donate      NaN
# 3      1500215577817886725  emergency  @GlobalGiving  emergency      NaN
# 4      1500215577817886725    hungary  @GlobalGiving    hungary      NaN
# ...                    ...        ...            ...        ...      ...
# 11310  1493639941867200514     relief     @WCKitchen     relief      NaN
# 11311  1493639941867200514       team     @WCKitchen       team      NaN
# 11312  1493639941867200514     travel     @WCKitchen     travel      NaN
# 11313  1493639941867200514        wck     @WCKitchen        wck      NaN
# 11314  1493639941867200514       work     @WCKitchen       work      NaN
#
#        modularity_class
# 0                   0.0
# 1                   2.0
# 2                   6.0
# 3                   3.0
# 4                   8.0
# ...                 ...
# 11310               2.0
# 11311               3.0
# 11312               7.0
# 11313               8.0
# 11314               6.0
#
# [11315 rows x 6 columns]

# %% [markdown]
# ## summary table of brands, modularity class, and terms

# %% [markdown]
# ### Get rid of the outlier segment

# %%
adj_list_with_community_label.modularity_class.value_counts(normalize=True)
# Out:
# 7.0    0.219655
# 8.0    0.149447
# 0.0    0.131031
# 1.0    0.130235
# 5.0    0.123152
# 3.0    0.121116
# 2.0    0.088004
# 6.0    0.035060
# 4.0    0.002302
# Name: modularity_class, dtype: float64

# %%
segments_to_include = adj_list_with_community_label.modularity_class.value_counts(normalize=True)
segments_to_include = segments_to_include[segments_to_include.values > 0.08].index.values
segments_to_include
# Out:
# array([7., 8., 0., 1., 5., 3., 2.])

# %%
adj_list_with_community_label = adj_list_with_community_label[adj_list_with_community_label.modularity_class.isin(segments_to_include)]

# %%
adj_list_with_community_label.modularity_class.value_counts()
# Out:
# 7.0    2481
# 8.0    1688
# 0.0    1480
# 1.0    1471
# 5.0    1391
# 3.0    1368
# 2.0     994
# Name: modularity_class, dtype: int64

# %%
adj_list_with_community_label.brand.value_counts(normalize = True)
# Out:
# @Refugees           0.167663
# @WCKitchen          0.163984
# @UNICEF             0.163432
# @ICRC               0.108894
# @RedCross           0.106042
# @SavetheChildren    0.079187
# @GlobalGiving       0.061437
# @MSF                0.060241
# @RESCUEorg          0.047917
# @UNHumanRights      0.041203
# Name: brand, dtype: float64

# %% [markdown]
# ### Summarizing top terms for each topic

# %% [raw]
# Summarizing top terms for each topic by brand

# %%
adj_list_with_community_label.stb.freq(['brand', 'modularity_class', 'Label']).sort_values('brand')
# Out:
#               brand  modularity_class     Label  count   percent  \
# 2648  @GlobalGiving               0.0        15      1  0.009197
# 2540  @GlobalGiving               8.0  response      1  0.009197
# 2539  @GlobalGiving               8.0   romania      1  0.009197
# 2538  @GlobalGiving               8.0   russian      1  0.009197
# 2537  @GlobalGiving               8.0   shelter      1  0.009197
# ...             ...               ...       ...    ...       ...
# 1632     @WCKitchen               5.0    russia      1  0.009197
# 1631     @WCKitchen               5.0     thing      1  0.009197
# 1630     @WCKitchen               5.0       use      1  0.009197
# 1628     @WCKitchen               7.0        16      1  0.009197
# 0        @WCKitchen               1.0     thank    270  2.483215
#
#       cumulative_count  cumulative_percent
# 2648             10873          100.000000
# 2540             10765           99.006714
# 2539             10764           98.997517
# 2538             10763           98.988320
# 2537             10762           98.979123
# ...                ...                 ...
# 1632              9857           90.655753
# 1631              9856           90.646556
# 1630              9855           90.637359
# 1628              9853           90.618964
# 0                  270            2.483215
#
# [2649 rows x 7 columns]

# %% [raw]
# Summarizing top terms for each conversation cluster ("modularity class")

# %%
top_terms_by_brand_ModClass = adj_list_with_community_label.stb.freq(['brand', 'modularity_class', 'Label' ]).sort_values('brand')
top_terms_by_brand_ModClass.to_csv('top_terms_by_brand_ModClass.csv', index=False)

# %%
top_terms_by_brand_ModClass[top_terms_by_brand_ModClass.modularity_class == 0].sort_values('count', ascending = False)[:20]
# Out:
#                 brand  modularity_class          Label  count   percent  \
# 7           @Refugees               0.0        refugee     71  0.652994
# 26          @Refugees               0.0          unhcr     33  0.303504
# 74            @UNICEF               0.0             19     19  0.174745
# 73            @UNICEF               0.0          covid     19  0.174745
# 98            @UNICEF               0.0  foreverychild     16  0.147153
# 109         @Refugees               0.0          world     15  0.137956
# 137         @Refugees               0.0           high     13  0.119562
# 135           @UNICEF               0.0        climate     13  0.119562
# 146           @UNICEF               0.0         school     12  0.110365
# 145           @UNICEF               0.0          world     12  0.110365
# 168         @Refugees               0.0   commissioner     11  0.101168
# 199             @ICRC               0.0           live     10  0.091971
# 183  @SavetheChildren               0.0      education     10  0.091971
# 182  @SavetheChildren               0.0          world     10  0.091971
# 176        @WCKitchen               0.0        refugee     10  0.091971
# 188         @Refugees               0.0     disability     10  0.091971
# 179           @UNICEF               0.0      education     10  0.091971
# 205           @UNICEF               0.0           risk      9  0.082774
# 209  @SavetheChildren               0.0         school      9  0.082774
# 206           @UNICEF               0.0         centre      9  0.082774
#
#      cumulative_count  cumulative_percent
# 7                1020            9.381036
# 26               1853           17.042215
# 74               3049           28.041939
# 73               3030           27.867194
# 98               3469           31.904718
# 109              3637           33.449830
# 137              4024           37.009105
# 135              3998           36.769981
# 146              4136           38.039180
# 145              4124           37.928814
# 168              4388           40.356847
# 199              4705           43.272326
# 183              4545           41.800791
# 182              4535           41.708820
# 176              4475           41.156994
# 188              4595           42.260646
# 179              4505           41.432907
# 205              4759           43.768969
# 209              4795           44.100064
# 206              4768           43.851743

# %%
top_terms = top_terms_per_segment(top_terms_by_brand_ModClass, 'modularity_class', 25)
top_terms
# Out:
#               0.0               1.0           2.0            3.0  \
# 0         refugee             thank          need            red
# 1           unhcr           support          home          cross
# 2              19     chefjoseandre        relief          learn
# 3           covid         sambloch1          life          blood
# 4   foreverychild          natemook        health             hi
# 5           world          grateful      displace           team
# 6            high            effort        crisis           food
# 7         climate        appreciate          fund        provide
# 8          school          continue   unicefchief       donation
# 9    commissioner           ongoing        worker  international
# 10           live        generosity  globalgiving            aid
# 11      education  standwithukraine          save      emergency
# 12     disability             share     nonprofit            msf
# 13           risk      matthewjdowd          care         supply
# 14         centre              love        access       american
# 15      challenge             hello     community        medical
# 16           hope         highlight       torture      ukrainian
# 17     adaptation              mean            gt         ground
# 18          ready        incredible           kit     assistance
# 19           hour         wckitchen    protection      committee
# 20  filippograndi              icrc      critical           time
# 21            way          surround         woman         member
# 22          begin          generous          area           fuel
# 23         urgent         important         bring   neighbouring
# 24           plan             trust          meet         remain
#
#                5.0        7.0              8.0
# 0         civilian      child              wck
# 1              war    ukraine           people
# 2             rule       flee             meal
# 3     humanitarian     unicef  chefsforukraine
# 4            right   conflict              amp
# 5            human       year            serve
# 6          protect     family              irc
# 7        mbachelet        old       restaurant
# 8             safe       help            fresh
# 9           target    country              hot
# 10        detainee      peace          partner
# 11           state      force           border
# 12  infrastructure        kid           poland
# 13        hospital    million              day
# 14        preserve      scale        volunteer
# 15          rights   escalate         response
# 16       essential      today     displacement
# 17         deliver     safety          station
# 18        humanity  situation              000
# 19        mariupol      young          kitchen
# 20          action       seek            local
# 21         passage       know         thousand
# 22    organization      leave             cook
# 23        casualty      water              new
# 24          report        end          shelter

# %% [markdown]
# ### Topic names

# %%
communities = top_terms.columns
modclass_names = ['refugee_assistance','solidarity','humanitarian','medical','military','family','meals']

name_dict = dict(zip(communities, modclass_names))
name_dict
# Out:
# {0.0: 'refugee_assistance',
#  1.0: 'solidarity',
#  2.0: 'humanitarian',
#  3.0: 'medical',
#  5.0: 'military',
#  7.0: 'family',
#  8.0: 'meals'}

# %%
top_terms.columns = modclass_names
top_terms.to_csv('top_terms_by_modclass.csv', index = False)

# %%
top_terms
# Out:
#    refugee_assistance        solidarity  humanitarian        medical  \
# 0             refugee             thank          need            red
# 1               unhcr           support          home          cross
# 2                  19     chefjoseandre        relief          learn
# 3               covid         sambloch1          life          blood
# 4       foreverychild          natemook        health             hi
# 5               world          grateful      displace           team
# 6                high            effort        crisis           food
# 7             climate        appreciate          fund        provide
# 8              school          continue   unicefchief       donation
# 9        commissioner           ongoing        worker  international
# 10               live        generosity  globalgiving            aid
# 11          education  standwithukraine          save      emergency
# 12         disability             share     nonprofit            msf
# 13               risk      matthewjdowd          care         supply
# 14             centre              love        access       american
# 15          challenge             hello     community        medical
# 16               hope         highlight       torture      ukrainian
# 17         adaptation              mean            gt         ground
# 18              ready        incredible           kit     assistance
# 19               hour         wckitchen    protection      committee
# 20      filippograndi              icrc      critical           time
# 21                way          surround         woman         member
# 22              begin          generous          area           fuel
# 23             urgent         important         bring   neighbouring
# 24               plan             trust          meet         remain
#
#           military     family            meals
# 0         civilian      child              wck
# 1              war    ukraine           people
# 2             rule       flee             meal
# 3     humanitarian     unicef  chefsforukraine
# 4            right   conflict              amp
# 5            human       year            serve
# 6          protect     family              irc
# 7        mbachelet        old       restaurant
# 8             safe       help            fresh
# 9           target    country              hot
# 10        detainee      peace          partner
# 11           state      force           border
# 12  infrastructure        kid           poland
# 13        hospital    million              day
# 14        preserve      scale        volunteer
# 15          rights   escalate         response
# 16       essential      today     displacement
# 17         deliver     safety          station
# 18        humanity  situation              000
# 19        mariupol      young          kitchen
# 20          action       seek            local
# 21         passage       know         thousand
# 22    organization      leave             cook
# 23        casualty      water              new
# 24          report        end          shelter

# %%
adj_list_with_community_label['topic'] = [name_dict.get(n, n) for n in adj_list_with_community_label.modularity_class]
# Out:
# <ipython-input-21-833fdc59e167>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adj_list_with_community_label['topic'] = [name_dict.get(n, n) for n in adj_list_with_community_label.modularity_class]

# %%
adj_list_with_community_label.topic.value_counts()
# Out:
# family                2481
# meals                 1688
# refugee_assistance    1480
# solidarity            1471
# military              1391
# medical               1368
# humanitarian           994
# Name: topic, dtype: int64

# %%
adj_list_with_community_label
# Out:
#                         id      Label          brand         Id  timeset  \
# 0      1500215577817886725         20  @GlobalGiving         20      NaN
# 1      1500215577817886725   critical  @GlobalGiving   critical      NaN
# 3      1500215577817886725  emergency  @GlobalGiving  emergency      NaN
# 4      1500215577817886725    hungary  @GlobalGiving    hungary      NaN
# 5      1500215577817886725      learn  @GlobalGiving      learn      NaN
# ...                    ...        ...            ...        ...      ...
# 11309  1493639941867200514    refugee     @WCKitchen    refugee      NaN
# 11310  1493639941867200514     relief     @WCKitchen     relief      NaN
# 11311  1493639941867200514       team     @WCKitchen       team      NaN
# 11312  1493639941867200514     travel     @WCKitchen     travel      NaN
# 11313  1493639941867200514        wck     @WCKitchen        wck      NaN
#
#        modularity_class               topic
# 0                   0.0  refugee_assistance
# 1                   2.0        humanitarian
# 3                   3.0             medical
# 4                   8.0               meals
# 5                   3.0             medical
# ...                 ...                 ...
# 11309               0.0  refugee_assistance
# 11310               2.0        humanitarian
# 11311               3.0             medical
# 11312               7.0              family
# 11313               8.0               meals
#
# [10873 rows x 7 columns]

# %% [markdown]
# ## Exporting files with top terms appended

# %%
adj_list_with_community_label.to_csv('adj_list_with_community_label.csv', index = False)

# %%
data.id = data.id.astype('str')
adj_list_with_community_label.id = adj_list_with_community_label.id.astype('str')

data_with_modclass = data.merge(adj_list_with_community_label[['id', 'topic']], on = 'id', how = 'left')
# Out:
# /opt/anaconda3/envs/social_content_analysis/lib/python3.8/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data.shape
# Out:
# (1338, 7)

# %%
data_with_modclass.drop_duplicates(subset='id', inplace=True)

# %%
data_with_modclass.shape
# Out:
# (1338, 8)

# %%
data_with_modclass.head()
# Out:
#                      id                 created_at  \
# 0   1500215577817886725  2022-03-05 21:04:01+00:00
# 13  1499909560030662661  2022-03-05 00:48:00+00:00
# 23  1499834444349386758  2022-03-04 19:49:31+00:00
# 35  1499833815874818052  2022-03-04 19:47:01+00:00
# 38  1499833431584350216  2022-03-04 19:45:30+00:00
#
#                                                  text          brand  \
# 0   UPDATE: Tabletochki Charity Foundation is one ...  @GlobalGiving
# 13  The link between #war and #hunger is clear—yet...  @GlobalGiving
# 23  @ItsFangs Thank you so much for showing your s...  @GlobalGiving
# 35  @Kellyrei007 Thank you so much for showing you...  @GlobalGiving
# 38  @jerryg125 Thank you for sharing! 🙌 🙌 #StandWi...  @GlobalGiving
#
#     polarity_score  subjectivity_score  \
# 0          0.34375              0.5125
# 13         0.06250              0.5000
# 23         0.07500              0.3250
# 35         0.25000              0.2000
# 38         0.00000              0.0000
#
#                                        processed_text               topic
# 0   update tabletochki charity foundation 20 nonpr...  refugee_assistance
# 13  link war hunger clear — overlook ukraine russi...            military
# 23  @itsfang thank support help community ukraine ...        humanitarian
# 35        @kellyrei007 thank support standwithukraine          solidarity
# 38        @jerryg125 thank share 🙌 🙌 standwithukraine          solidarity

# %%
data_with_modclass.topic.value_counts(normalize=True)
# Out:
# solidarity            0.292998
# family                0.159817
# meals                 0.143075
# medical               0.110350
# refugee_assistance    0.108828
# humanitarian          0.098174
# military              0.086758
# Name: topic, dtype: float64

# %%
data_with_modclass.to_csv('data_with_topic_added.csv', index = False)

# %% [markdown]
# ### Summary of the Topics (e.g. ModClass) by Brand

# %%
adj_list_with_community_label.pivot_table(index = 'topic', columns = 'brand', aggfunc='size')
# Out:
# brand               @GlobalGiving  @ICRC  @MSF  @RESCUEorg  @RedCross  \
# topic
# family                         82    243   106         124        165
# humanitarian                  117    130    96          55         67
# meals                          78    142   128          95        115
# medical                        75    134   148          44        565
# military                       38    424   105          91        117
# refugee_assistance             97     78    61          79         57
# solidarity                    181     33    11          33         67
#
# brand               @Refugees  @SavetheChildren  @UNHumanRights  @UNICEF  \
# topic
# family                    478               343              56      758
# humanitarian              165                70              26      214
# meals                     295                76              50      148
# medical                   160                59              23       88
# military                  156                89             197      147
# refugee_assistance        484               152              66      345
# solidarity                 85                72              30       77
#
# brand               @WCKitchen
# topic
# family                     126
# humanitarian                54
# meals                      561
# medical                     72
# military                    27
# refugee_assistance          61
# solidarity                 882

# %%
adj_list_with_community_label.pivot_table(index = 'topic', columns = 'brand', aggfunc='size').to_csv('author mentions by topic.csv', index = True)

# %%
top_terms_per_segment(top_terms_by_brand_ModClass, 'brand', 25)
# Out:
#        @GlobalGiving           @ICRC          @MSF       @RESCUEorg  \
# 0              thank         ukraine       ukraine          ukraine
# 1            support          people          team            thank
# 2            ukraine        civilian        people              irc
# 3         generosity             war     emergency     humanitarian
# 4             relief        conflict           msf           crisis
# 5               fund            rule       medical             need
# 6   standwithukraine    humanitarian          need           people
# 7             people            help      response          support
# 8              share            need      conflict             help
# 9            partner             aid        access  refugeeswelcome
# 10      globalgiving            life        crisis           urgent
# 11              time         protect        health          refugee
# 12         nonprofit       situation      mariupol         civilian
# 13          donation          family     situation          welcome
# 14            crisis          target         learn         critical
# 15         community         support           kit              war
# 16              need  infrastructure        supply             late
# 17      organization           water          care             year
# 18            family            live       provide         response
# 19           provide        detainee  humanitarian            world
# 20              look            safe          seek        extremely
# 21              risk           state      fighting             life
# 22        incredible           cross       country            human
# 23              area             red      activity           russia
# 24             bring        hospital      hospital           family
#
#         @RedCross     @Refugees @SavetheChildren @UNHumanRights  \
# 0             red       ukraine            child        support
# 1           cross       refugee          ukraine          right
# 2         ukraine        people          support          human
# 3           learn          flee           family            amp
# 4           blood         unhcr         conflict      mbachelet
# 5            help          help              kid        ukraine
# 6              hi       support            thank       civilian
# 7            team       country             help         rights
# 8           thank         force            learn         people
# 9            food       million        education         action
# 10       donation          home            world         report
# 11        provide  humanitarian           school          march
# 12  international          need             need       casualty
# 13            aid      displace             flee          hrc49
# 14           need        crisis             time       military
# 15        support        safety             life            law
# 16         supply         today             year      violation
# 17       american      conflict           crisis            new
# 18      ukrainian       provide         continue         ensure
# 19        medical         thank             safe    development
# 20         ground         world              amp          chief
# 21      committee        family             food          learn
# 22           fuel          life             live        iwd2022
# 23         member          high            reach        justice
# 24           time    assistance           impact         russia
#
#           @UNICEF       @WCKitchen
# 0           child            thank
# 1         ukraine          support
# 2          unicef    chefjoseandre
# 3         support              wck
# 4        conflict        sambloch1
# 5            need             meal
# 6            year         grateful
# 7          family         natemook
# 8             old  chefsforukraine
# 9            help           effort
# 10          peace       appreciate
# 11           life              amp
# 12         health          ukraine
# 13          covid           family
# 14             19            serve
# 15          scale           relief
# 16        country         continue
# 17          today           people
# 18       escalate          ongoing
# 19        protect       restaurant
# 20  foreverychild             help
# 21           flee              hot
# 22          right          partner
# 23        climate            fresh
# 24         people           border

# %%
top_terms_per_segment(top_terms_by_brand_ModClass, 'brand', 25).to_csv('top terms by author.csv', index=True)
