# %% [markdown]
# # Init

# %%
import pandas as pd
import numpy as np
import sidetable 
import os

np.random.seed(67)

# %% [raw]
# Function to return top # of terms per desired segment

# %%
def top_terms_per_segment(summary_table, segment, top_n):
    list_of_segments = np.unique(summary_table[segment])
    top_terms = []
    
    for group in list_of_segments:
        filtered_table = summary_table[summary_table[segment] == group].sort_values('count', ascending = False)
        most_frequent_terms = pd.Series(filtered_table.Label.values)
        most_frequent_terms.drop_duplicates(inplace = True)
        #print(most_frequent_terms[0:top_n])
        most_frequent_terms = most_frequent_terms[0:top_n] 
        most_frequent_terms.reset_index(inplace=True, drop=True)
        top_terms.append(most_frequent_terms)
        
    table_out = pd.DataFrame(top_terms).transpose()
    table_out.columns = list_of_segments
    
    return table_out

# %% [markdown]
# ## Load files

# %% [raw]
# original data file

# %%
data = pd.read_csv('data_backup.csv')

# %% [raw]
# adjacency list with community appended

# %%
community_appended_adj_list = pd.read_csv('adjacency list export with modularity class.csv')

# %%
community_appended_adj_list.rename({'source':'id','Target':'Label'}, axis=1, inplace=True)

# %%
community_appended_adj_list.head()
# Out:
#                     id    Label  community
# 0  1534282318311051264   change          0
# 1  1534282318311051264  climate          0
# 2  1534282318311051264      far          0
# 3  1534282318311051264   global          0
# 4  1534282318311051264   impact          0

# %% [raw]
# adjacency list

# %%
adj_list_with_brand_label = pd.read_csv('adjacency_list_for_merging.csv')

# %%
adj_list_with_brand_label.head()
# Out:
#                     id   Target        brand
# 0  1534282318311051264   change  @SierraClub
# 1  1534282318311051264  climate  @SierraClub
# 2  1534282318311051264      far  @SierraClub
# 3  1534282318311051264   global  @SierraClub
# 4  1534282318311051264   impact  @SierraClub

# %%
adj_list_with_brand_label.rename({'Target':'Label'}, axis=1, inplace=True)

# %% [markdown]
# # Append Community Labels and summarize

# %% [markdown]
# ## Append labels

# %%
adj_list_with_brand_label = adj_list_with_brand_label.merge(community_appended_adj_list, how = 'left', on=['id','Label'])

# %%
adj_list_with_brand_label
# Out:
#                          id           Label        brand  community
# 0       1534282318311051264          change  @SierraClub          0
# 1       1534282318311051264         climate  @SierraClub          0
# 2       1534282318311051264             far  @SierraClub          0
# 3       1534282318311051264          global  @SierraClub          0
# 4       1534282318311051264          impact  @SierraClub          0
# ...                     ...             ...          ...        ...
# 153065  1395052880063762438            good        @NRDC          3
# 153066  1395052880063762438            help        @NRDC          3
# 153067  1395052880063762438  infrastructure        @NRDC          3
# 153068  1395052880063762438             job        @NRDC          3
# 153069  1395052880063762438         support        @NRDC          3
#
# [153070 rows x 4 columns]

# %% [markdown]
# ## summary table of brands, modularity class, and terms

# %% [markdown]
# ### Get rid of the outlier segment

# %% [raw]
# changing 'community' to 'modularity class' to be backwards compatible with previous versions :)

# %%
adj_list_with_brand_label.rename({'community':'modularity_class'},axis='columns',inplace=True)

# %%
adj_list_with_brand_label.modularity_class.value_counts(normalize=True)
# Out:
# 0     0.168701
# 6     0.153152
# 9     0.139511
# 1     0.126197
# 4     0.110910
# 3     0.080270
# 7     0.066349
# 8     0.059724
# 10    0.046475
# 2     0.025916
# 5     0.022793
# Name: modularity_class, dtype: float64

# %%
segments_to_include = adj_list_with_brand_label.modularity_class.value_counts(normalize=True)
segments_to_include = segments_to_include[segments_to_include.values > 0.08].index.values
segments_to_include
# Out:
# array([0, 6, 9, 1, 4, 3])

# %%
adj_list_with_brand_label = adj_list_with_brand_label[adj_list_with_brand_label.modularity_class.isin(segments_to_include)]

# %%
adj_list_with_brand_label.modularity_class.value_counts()
# Out:
# 0    25823
# 6    23443
# 9    21355
# 1    19317
# 4    16977
# 3    12287
# Name: modularity_class, dtype: int64

# %%
adj_list_with_brand_label.brand.value_counts(normalize = True)
# Out:
# @Earthjustice      0.138412
# @foe_us            0.137431
# @NRDC              0.127775
# @ewg               0.117590
# @greenpeaceusa     0.098237
# @SierraClub        0.093883
# @UCSUSA            0.087230
# @OurOcean          0.084428
# @RnfrstAlliance    0.062558
# @earthisland       0.052457
# Name: brand, dtype: float64

# %% [markdown]
# ### Summarizing top terms for each topic

# %% [raw]
# Summarizing top terms for each topic by brand

# %%
adj_list_with_brand_label.stb.freq(['brand', 'modularity_class', 'Label']).sort_values('brand')
# Out:
#                 brand  modularity_class    Label  count   percent  \
# 12411   @Earthjustice                 0       50      1  0.000839
# 3562    @Earthjustice                 3      job      9  0.007550
# 3561    @Earthjustice                 3      new      9  0.007550
# 3560    @Earthjustice                 3   tackle      9  0.007550
# 3559    @Earthjustice                 4  country      9  0.007550
# ...               ...               ...      ...    ...       ...
# 3591   @greenpeaceusa                 6    trump      8  0.006711
# 3592   @greenpeaceusa                 6   report      8  0.006711
# 3593   @greenpeaceusa                 6    learn      8  0.006711
# 3585   @greenpeaceusa                 9    today      8  0.006711
# 5248   @greenpeaceusa                 6   forest      5  0.004195
#
#        cumulative_count  cumulative_percent
# 12411            119202          100.000000
# 3562              90191           75.662321
# 3561              90182           75.654771
# 3560              90173           75.647221
# 3559              90164           75.639670
# ...                 ...                 ...
# 3591              90442           75.872888
# 3592              90450           75.879599
# 3593              90458           75.886311
# 3585              90394           75.832620
# 5248             101798           85.399574
#
# [12412 rows x 7 columns]

# %% [raw]
# Summarizing top terms for each conversation cluster ("modularity class")

# %%
top_terms_by_brand_ModClass = adj_list_with_brand_label.stb.freq(['brand', 'modularity_class', 'Label' ]).sort_values('brand')
top_terms_by_brand_ModClass.to_csv('top_terms_by_brand_ModClass.csv', index=False)

# %%
top_terms_by_brand_ModClass[top_terms_by_brand_ModClass.modularity_class == 0].sort_values('count', ascending = False)[:20]
# Out:
#              brand  modularity_class    Label  count   percent  \
# 12  @greenpeaceusa                 0     fuel    300  0.251674
# 13  @greenpeaceusa                 0  climate    294  0.246640
# 15  @greenpeaceusa                 0   fossil    285  0.239090
# 16   @Earthjustice                 0  climate    278  0.233218
# 20           @NRDC                 0  climate    256  0.214761
# 21         @foe_us                 0  climate    232  0.194628
# 31         @foe_us                 0     fuel    195  0.163588
# 32         @foe_us                 0   fossil    191  0.160232
# 34     @SierraClub                 0  climate    190  0.159393
# 37   @Earthjustice                 0     fuel    186  0.156038
# 41         @UCSUSA                 0  climate    179  0.150165
# 44   @Earthjustice                 0   fossil    167  0.140098
# 52           @NRDC                 0   energy    143  0.119964
# 54   @Earthjustice                 0   energy    133  0.111575
# 55   @Earthjustice                 0    clean    131  0.109897
# 56     @SierraClub                 0   energy    130  0.109059
# 57   @Earthjustice                 0   crisis    128  0.107381
# 60           @NRDC                 0    clean    125  0.104864
# 61     @SierraClub                 0    clean    123  0.103186
# 63           @NRDC                 0     need    122  0.102347
#
#     cumulative_count  cumulative_percent
# 12              4908            4.117381
# 13              5202            4.364021
# 15              5774            4.843878
# 16              6052            5.077096
# 20              7087            5.945370
# 21              7319            6.139998
# 31              9461            7.936947
# 32              9652            8.097180
# 34             10033            8.416805
# 37             10595            8.888274
# 41             11320            9.496485
# 44             11837            9.930203
# 52             13052           10.949481
# 54             13327           11.180182
# 55             13458           11.290079
# 56             13588           11.399138
# 57             13716           11.506518
# 60             14093           11.822788
# 61             14216           11.925974
# 63             14461           12.131508

# %%
top_terms = top_terms_per_segment(top_terms_by_brand_ModClass, 'modularity_class', 25)
top_terms
# Out:
#              0            1                3              4               6  \
# 0         fuel        ocean          climate          earth             oil
# 1      climate          sea              act         island             amp
# 2       fossil       forest             pass          ocean           biden
# 3       energy   rainforest          justice         friend             gas
# 4        clean         know              job            ucs             big
# 5       crisis        world         congress  environmental         climate
# 6         need       people              amp          learn  administration
# 7       action       nature       investment          today            land
# 8          amp         work        community           week          public
# 9         time    community   infrastructure           look         million
# 10      change         tree            ocean           join           potus
# 11      future        today           create            new            fuel
# 12    industry  sustainable             urge            day           lease
# 13         end       farmer  buildbackbetter           work         federal
# 14        stop       marine          address        plastic        drilling
# 15         oil        learn    environmental        science      protection
# 16   community         help             need        climate       president
# 17       ocean       specie            clean          issue         billion
# 18   pollution         like             nrdc           know          fossil
# 19   renewable      climate             care        project        industry
# 20         gas       planet              law          check             new
# 21       power         year      legislation           free           court
# 22         new         life           senate           help         protect
# 23  transition         need            today          share          profit
# 24      people      protect            potus          great           trump
#
#                   9
# 0             toxic
# 1              pfas
# 2              food
# 3   foreverchemical
# 4              safe
# 5          chemical
# 6           product
# 7          exposure
# 8              vote
# 9              lead
# 10          protect
# 11              fda
# 12           health
# 13       california
# 14              ewg
# 15     californians
# 16              ban
# 17            child
# 18            water
# 19              use
# 20          support
# 21             care
# 22             harm
# 23            limit
# 24           family

# %% [markdown]
# ### Topic names

# %% [raw]
# NOTE: this step is done by manually looking at the output of the line above...a bit kludgy

# %%
communities = top_terms.columns
modclass_names = ['fossil_fuels','natural_habitats','climate_legislation','earth_community','biden_administration','pollution']

name_dict = dict(zip(communities, modclass_names))
name_dict
# Out:
# {0: 'fossil_fuels',
#  1: 'natural_habitats',
#  3: 'climate_legislation',
#  4: 'earth_community',
#  6: 'biden_administration',
#  9: 'pollution'}

# %%
top_terms.columns = modclass_names
top_terms.to_csv('top_terms_by_modclass.csv', index = False)

# %%
top_terms
# Out:
#    fossil_fuels natural_habitats climate_legislation earth_community  \
# 0          fuel            ocean             climate           earth
# 1       climate              sea                 act          island
# 2        fossil           forest                pass           ocean
# 3        energy       rainforest             justice          friend
# 4         clean             know                 job             ucs
# 5        crisis            world            congress   environmental
# 6          need           people                 amp           learn
# 7        action           nature          investment           today
# 8           amp             work           community            week
# 9          time        community      infrastructure            look
# 10       change             tree               ocean            join
# 11       future            today              create             new
# 12     industry      sustainable                urge             day
# 13          end           farmer     buildbackbetter            work
# 14         stop           marine             address         plastic
# 15          oil            learn       environmental         science
# 16    community             help                need         climate
# 17        ocean           specie               clean           issue
# 18    pollution             like                nrdc            know
# 19    renewable          climate                care         project
# 20          gas           planet                 law           check
# 21        power             year         legislation            free
# 22          new             life              senate            help
# 23   transition             need               today           share
# 24       people          protect               potus           great
#
#    biden_administration        pollution
# 0                   oil            toxic
# 1                   amp             pfas
# 2                 biden             food
# 3                   gas  foreverchemical
# 4                   big             safe
# 5               climate         chemical
# 6        administration          product
# 7                  land         exposure
# 8                public             vote
# 9               million             lead
# 10                potus          protect
# 11                 fuel              fda
# 12                lease           health
# 13              federal       california
# 14             drilling              ewg
# 15           protection     californians
# 16            president              ban
# 17              billion            child
# 18               fossil            water
# 19             industry              use
# 20                  new          support
# 21                court             care
# 22              protect             harm
# 23               profit            limit
# 24                trump           family

# %%
adj_list_with_brand_label['topic'] = [name_dict.get(n, n) for n in adj_list_with_brand_label.modularity_class]
# Out:
# /var/folders/0n/jtvl1jfx6hj3j5xbd39_bfp40000gp/T/ipykernel_26158/676405628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adj_list_with_brand_label['topic'] = [name_dict.get(n, n) for n in adj_list_with_brand_label.modularity_class]

# %%
adj_list_with_brand_label.topic.value_counts()
# Out:
# fossil_fuels            25823
# biden_administration    23443
# pollution               21355
# natural_habitats        19317
# earth_community         16977
# climate_legislation     12287
# Name: topic, dtype: int64

# %%
adj_list_with_brand_label
# Out:
#                          id           Label        brand  modularity_class  \
# 0       1534282318311051264          change  @SierraClub                 0
# 1       1534282318311051264         climate  @SierraClub                 0
# 2       1534282318311051264             far  @SierraClub                 0
# 3       1534282318311051264          global  @SierraClub                 0
# 4       1534282318311051264          impact  @SierraClub                 0
# ...                     ...             ...          ...               ...
# 153065  1395052880063762438            good        @NRDC                 3
# 153066  1395052880063762438            help        @NRDC                 3
# 153067  1395052880063762438  infrastructure        @NRDC                 3
# 153068  1395052880063762438             job        @NRDC                 3
# 153069  1395052880063762438         support        @NRDC                 3
#
#                       topic
# 0              fossil_fuels
# 1              fossil_fuels
# 2              fossil_fuels
# 3              fossil_fuels
# 4              fossil_fuels
# ...                     ...
# 153065  climate_legislation
# 153066  climate_legislation
# 153067  climate_legislation
# 153068  climate_legislation
# 153069  climate_legislation
#
# [119202 rows x 5 columns]

# %% [markdown]
# ## Exporting files with top terms appended

# %%
adj_list_with_brand_label.to_csv('adj_list_with_brand_label.csv', index = False)

# %%
data.id = data.id.astype('str')
adj_list_with_brand_label.id = adj_list_with_brand_label.id.astype('str')

data_with_modclass = data.merge(adj_list_with_brand_label[['id', 'topic']], on = 'id', how = 'left')
# Out:
# /Users/alexanderliss/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data.shape
# Out:
# (23817, 7)

# %%
data_with_modclass.drop_duplicates(subset='id', inplace=True)

# %%
data_with_modclass.shape
# Out:
# (23817, 8)

# %%
data_with_modclass.head()
# Out:
#                      id                 created_at  \
# 0   1534282318311051264  2022-06-07 21:13:04+00:00
# 6   1534252609468518402  2022-06-07 19:15:01+00:00
# 7   1534246717301874688  2022-06-07 18:51:36+00:00
# 8   1534218707739746304  2022-06-07 17:00:18+00:00
# 14  1534193123110289410  2022-06-07 15:18:39+00:00
#
#                                                  text        brand  \
# 0   Global Impact's a podcast about amplifying voi...  @SierraClub
# 6   Important piece from @VFWHQ 👇👇👇\n\n"Nature-bas...  @SierraClub
# 7   Paid for by Sierra Club Independent Action, ht...  @SierraClub
# 8   The attack on our democracy didn’t end on Janu...  @SierraClub
# 14  The communities in and around El Paso, TX have...  @SierraClub
#
#     polarity_score  subjectivity_score  \
# 0         0.025000            0.250000
# 6         0.257143            0.657143
# 7         0.050000            0.112500
# 8        -0.300000            0.400000
# 14        0.166667            0.333333
#
#                                        processed_text             topic
# 0   global impact podcast amplify voice global gra...      fossil_fuels
# 6   important piece @vfwhq 👇 👇 👇 nature base progr...               NaN
# 7   pay sierra club independent action authorize c...      fossil_fuels
# 8   attack democracy end january 6 2021 voter supp...         pollution
# 14  community el paso tx work conserve castner ran...  natural_habitats

# %%
data_with_modclass.topic.value_counts(normalize=True)
# Out:
# natural_habitats        0.206362
# earth_community         0.186769
# fossil_fuels            0.182043
# pollution               0.173227
# biden_administration    0.164755
# climate_legislation     0.086844
# Name: topic, dtype: float64

# %%
data_with_modclass.to_csv('data_with_topic_added.csv', index = False)

# %% [markdown]
# ### Summary of the Topics (e.g. ModClass) by Brand

# %%
adj_list_with_brand_label.pivot_table(index = 'topic', columns = 'brand', aggfunc='size')
# Out:
# brand                 @Earthjustice  @NRDC  @OurOcean  @RnfrstAlliance  \
# topic
# biden_administration           5284   2320        816              315
# climate_legislation            1128   2717       1108              583
# earth_community                1251   1721       2955             1255
# fossil_fuels                   4113   4039       1406              989
# natural_habitats               2493   2189       3322             3442
# pollution                      2230   2245        457              873
#
# brand                 @SierraClub  @UCSUSA  @earthisland   @ewg  @foe_us  \
# topic
# biden_administration         2173     1638           746    681     7266
# climate_legislation          2215     2266           186    282      882
# earth_community              1251     1885          3436    719     1002
# fossil_fuels                 3344     2546           659    840     3199
# natural_habitats             1311      878           830    991     2082
# pollution                     897     1185           396  10504     1951
#
# brand                 @greenpeaceusa
# topic
# biden_administration            2204
# climate_legislation              920
# earth_community                 1502
# fossil_fuels                    4688
# natural_habitats                1779
# pollution                        617

# %%
adj_list_with_brand_label.pivot_table(index = 'topic', columns = 'brand', aggfunc='size').to_csv('author mentions by topic.csv', index = True)

# %%
top_terms_per_segment(top_terms_by_brand_ModClass, 'brand', 25)
# Out:
#      @Earthjustice           @NRDC @OurOcean @RnfrstAlliance @SierraClub  \
# 0          climate         climate     ocean          forest     climate
# 1              oil          energy       sea      rainforest      energy
# 2            biden           clean    friend           world       clean
# 3   administration            need      know          people         amp
# 4             fuel            fuel   climate          nature        fuel
# 5              gas          action     learn         climate      fossil
# 6           fossil            time     today            work     justice
# 7           energy            pass      look       community         gas
# 8            clean          fossil    marine            tree         job
# 9           crisis          future       day     sustainable        pass
# 10         federal          change      work          farmer      crisis
# 11        drilling             amp      help            help  investment
# 12            land        congress     world         protect    congress
# 13      protection             gas      like          change         oil
# 14        industry             oil    change            grow      action
# 15           court           water      life          future      change
# 16          change             job      join             way        need
# 17         protect          crisis      need     agriculture        time
# 18        pipeline             act      live           human   community
# 19            time       community       let           share      public
# 20           trump  infrastructure      meet           learn        land
# 21           lease           biden       way            land         new
# 22         million          create     check            need       power
# 23          public            lead     share            year       biden
# 24           water         address    animal          action    industry
#
#             @UCSUSA   @earthisland             @ewg         @foe_us  \
# 0           climate          earth            toxic             oil
# 1               ucs         island             pfas             amp
# 2               act  environmental             food           biden
# 3            energy           week  foreverchemical             gas
# 4            change           join             safe         climate
# 5              pass            new         chemical             big
# 6          congress        plastic          product            fuel
# 7              need        climate         exposure          fossil
# 8             clean          issue             vote            land
# 9             biden           work             lead          public
# 10             join        project          protect         million
# 11           action           free              fda           potus
# 12          science         change           health           lease
# 13             fuel           year       california  administration
# 14              amp          today              ewg        drilling
# 15             urge         report     californians       president
# 16   administration          trump              ban         billion
# 17  buildbackbetter          thank            child        industry
# 18           fossil      community            water             new
# 19          justice            oil              use          crisis
# 20            today        protect          support          action
# 21           future           late             care          profit
# 22              oil       activist            limit           trump
# 23           public          story             harm            gulf
# 24       transition          world           family            year
#
#    @greenpeaceusa
# 0            fuel
# 1         climate
# 2          fossil
# 3             oil
# 4            need
# 5          action
# 6          energy
# 7          change
# 8          crisis
# 9            time
# 10            gas
# 11         future
# 12            end
# 13           stop
# 14      community
# 15       industry
# 16            amp
# 17         planet
# 18      renewable
# 19            new
# 20            big
# 21     transition
# 22          potus
# 23         people
# 24       drilling

# %%
top_terms_per_segment(top_terms_by_brand_ModClass, 'brand', 25).to_csv('top terms by author.csv', index=True)
