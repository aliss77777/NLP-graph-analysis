# %% [markdown]
# # Init

# %%
import pandas as pd
import numpy as np
import sidetable 
import os

np.random.seed(67)

# %% [raw]
# Function to return top # of terms per desired segment

# %%
def top_terms_per_segment(summary_table, segment, top_n):
    list_of_segments = np.unique(summary_table[segment])
    top_terms = []
    
    for group in list_of_segments:
        filtered_table = summary_table[summary_table[segment] == group].sort_values('count', ascending = False)
        most_frequent_terms = pd.Series(filtered_table.Label.values)
        most_frequent_terms.drop_duplicates(inplace = True)
        #print(most_frequent_terms[0:top_n])
        most_frequent_terms = most_frequent_terms[0:top_n] 
        most_frequent_terms.reset_index(inplace=True, drop=True)
        top_terms.append(most_frequent_terms)
        
    table_out = pd.DataFrame(top_terms).transpose()
    table_out.columns = list_of_segments
    
    return table_out

# %% [markdown]
# ## Load files

# %% [raw]
# original data file

# %%
data = pd.read_csv('data_backup.csv')

# %% [raw]
# adjacency list with community appended

# %%
community_appended_adj_list = pd.read_csv('adjacency list export with modularity class.csv')

# %%
community_appended_adj_list.rename({'source':'id','Target':'Label'}, axis=1, inplace=True)

# %%
community_appended_adj_list.head()
# Out:
#                     id     Label  community
# 0  1540683731630927874  increase          0
# 1  1540683731630927874       new          0
# 2  1540683731630927874    reduce          0
# 3  1540683731630927874     study          0
# 4  1540366146423095296     check          1

# %% [raw]
# adjacency list

# %%
adj_list_with_brand_label = pd.read_csv('adjacency_list_for_merging.csv')

# %%
adj_list_with_brand_label.head()
# Out:
#                     id    Target brand
# 0  1540683731630927874  increase  @ewg
# 1  1540683731630927874       new  @ewg
# 2  1540683731630927874    reduce  @ewg
# 3  1540683731630927874     study  @ewg
# 4  1540366146423095296     check  @ewg

# %%
adj_list_with_brand_label.rename({'Target':'Label'}, axis=1, inplace=True)

# %% [markdown]
# # Append Community Labels and summarize

# %% [markdown]
# ## Append labels

# %%
adj_list_with_brand_label = adj_list_with_brand_label.merge(community_appended_adj_list, how = 'left', on=['id','Label'])

# %%
adj_list_with_brand_label
# Out:
#                         id     Label  brand  community
# 0      1540683731630927874  increase   @ewg          0
# 1      1540683731630927874       new   @ewg          0
# 2      1540683731630927874    reduce   @ewg          0
# 3      1540683731630927874     study   @ewg          0
# 4      1540366146423095296     check   @ewg          1
# ...                    ...       ...    ...        ...
# 85083  1397962840724496386     human  @NRDC          0
# 85084  1397962840724496386     learn  @NRDC          0
# 85085  1397962839894085633       000  @NRDC          0
# 85086  1397962839894085633       new  @NRDC          0
# 85087  1397962839894085633     study  @NRDC          0
#
# [85088 rows x 4 columns]

# %% [markdown]
# ## summary table of brands, modularity class, and terms

# %% [markdown]
# ### Get rid of the outlier segment

# %% [raw]
# changing 'community' to 'modularity class' to be backwards compatible with previous versions :)

# %%
adj_list_with_brand_label.rename({'community':'modularity_class'},axis='columns',inplace=True)

# %%
adj_list_with_brand_label.modularity_class.value_counts(normalize=True)
# Out:
# 3    0.191484
# 0    0.179332
# 6    0.166910
# 2    0.162737
# 4    0.103622
# 1    0.087086
# 5    0.074006
# 7    0.034823
# Name: modularity_class, dtype: float64

# %%
segments_to_include = adj_list_with_brand_label.modularity_class.value_counts(normalize=True)
segments_to_include = segments_to_include[segments_to_include.values > 0.08].index.values
segments_to_include
# Out:
# array([3, 0, 6, 2, 4, 1])

# %%
adj_list_with_brand_label = adj_list_with_brand_label[adj_list_with_brand_label.modularity_class.isin(segments_to_include)]

# %%
adj_list_with_brand_label.modularity_class.value_counts()
# Out:
# 3    16293
# 0    15259
# 6    14202
# 2    13847
# 4     8817
# 1     7410
# Name: modularity_class, dtype: int64

# %% [raw]
# Adding a variable to capture descending order for sorting the topics

# %%
modularity_class_sort_order = adj_list_with_brand_label.modularity_class.value_counts().index

# %%
adj_list_with_brand_label.brand.value_counts(normalize = True)
# Out:
# @foe_us            0.215105
# @Earthjustice      0.211571
# @NRDC              0.200968
# @EnvDefenseFund    0.199504
# @ewg               0.172852
# Name: brand, dtype: float64

# %%
# same process as modularity class sort order
author_sort_order = adj_list_with_brand_label.brand.value_counts().index.values

# %% [markdown]
# ### Summarizing top terms for each topic

# %% [raw]
# Summarizing top terms for each topic by brand

# %%
adj_list_with_brand_label.stb.freq(['brand', 'modularity_class', 'Label']).sort_values('brand')
# Out:
#               brand  modularity_class     Label  count   percent  \
# 4917  @Earthjustice                 0      2021      1  0.001319
# 1725  @Earthjustice                 6      come     12  0.015825
# 1724  @Earthjustice                 6     lease     12  0.015825
# 1619  @Earthjustice                 0       day     13  0.017144
# 1618  @Earthjustice                 0      fuel     13  0.017144
# ...             ...               ...       ...    ...       ...
# 1761        @foe_us                 6  continue     11  0.014507
# 1760        @foe_us                 6      like     11  0.014507
# 1759        @foe_us                 6     toxic     11  0.014507
# 2075        @foe_us                 4     potus      9  0.011869
# 2458        @foe_us                 4       ban      7  0.009231
#
#       cumulative_count  cumulative_percent
# 4917             75828          100.000000
# 1725             60399           79.652635
# 1724             60387           79.636810
# 1619             59127           77.975154
# 1618             59114           77.958010
# ...                ...                 ...
# 1761             60828           80.218389
# 1760             60817           80.203882
# 1759             60806           80.189376
# 2075             64100           84.533418
# 2458             67316           88.774595
#
# [4918 rows x 7 columns]

# %% [raw]
# Summarizing top terms for each conversation cluster ("modularity class")

# %%
top_terms_by_brand_ModClass = adj_list_with_brand_label.stb.freq(['brand', 'modularity_class', 'Label' ]).sort_values('brand')
top_terms_by_brand_ModClass.to_csv('top_terms_by_brand_ModClass.csv', index=False)

# %%
top_terms_by_brand_ModClass[top_terms_by_brand_ModClass.modularity_class == 0].sort_values('count', ascending = False)[:20]
# Out:
#                brand  modularity_class     Label  count   percent  \
# 2    @EnvDefenseFund                 0   climate    493  0.650156
# 9    @EnvDefenseFund                 0    change    265  0.349475
# 19   @EnvDefenseFund                 0  emission    203  0.267711
# 30   @EnvDefenseFund                 0       new    189  0.249248
# 32   @EnvDefenseFund                 0    global    188  0.247930
# 37             @NRDC                 0   climate    182  0.240017
# 38   @EnvDefenseFund                 0   warming    180  0.237379
# 50     @Earthjustice                 0   climate    147  0.193860
# 54   @EnvDefenseFund                 0   methane    132  0.174078
# 56           @foe_us                 0   climate    129  0.170122
# 60           @foe_us                 0  emission    117  0.154297
# 61   @EnvDefenseFund                 0       gas    117  0.154297
# 68           @foe_us                 0       gas    108  0.142428
# 71   @EnvDefenseFund                 0     world    105  0.138471
# 76   @EnvDefenseFund                 0    carbon    101  0.133196
# 81   @EnvDefenseFund                 0     study     96  0.126602
# 88           @foe_us                 0       new     92  0.121327
# 106  @EnvDefenseFund                 0      year     85  0.112096
# 110  @EnvDefenseFund                 0       cut     83  0.109458
# 117  @EnvDefenseFund                 0    impact     79  0.104183
#
#      cumulative_count  cumulative_percent
# 2                1585            2.090257
# 9                3889            5.128712
# 19               6152            8.113098
# 30               8300           10.945825
# 32               8676           11.441684
# 37               9600           12.660231
# 38               9780           12.897610
# 50              11720           15.456032
# 54              12274           16.186633
# 56              12534           16.529514
# 60              13015           17.163844
# 61              13132           17.318141
# 68              13916           18.352060
# 71              14235           18.772749
# 76              14752           19.454555
# 81              15241           20.099436
# 88              15897           20.964551
# 106             17491           23.066677
# 110             17826           23.508467
# 117             18389           24.250936

# %% [raw]
# ?top_terms.reindex

# %% [raw]
# booty = top_terms.copy()

# %% [raw]
# booty

# %% [raw]
# booty = booty.reindex(columns=modularity_class_sort_order)

# %%
top_terms = top_terms_per_segment(top_terms_by_brand_ModClass, 'modularity_class', 25)
top_terms = top_terms.reindex(columns=modularity_class_sort_order)
top_terms
# Out:
#                   3           0               6               2  \
# 0             toxic     climate            fuel             oil
# 1              pfas      change           clean             big
# 2              food    emission          fossil             amp
# 3              safe         new          energy           biden
# 4   foreverchemical      global       pollution         climate
# 5          chemical     warming         climate            land
# 6           product     methane       community  administration
# 7          exposure         gas             air          public
# 8              vote       world        electric           potus
# 9              lead      carbon        industry             gas
# 10              fda       study             new         million
# 11           health        year         vehicle         federal
# 12       california         cut             gas        drilling
# 13          protect      impact          future            stop
# 14              ban        need           power      protection
# 15     californians      report           state           court
# 16              ewg      action             amp         protect
# 17              use        heat             job         billion
# 18            water  greenhouse           plant          profit
# 19            child      reduce            need        industry
# 20          support   scientist            coal            year
# 21            thank    solution             oil            huge
# 22             harm      crisis  infrastructure       president
# 23           family   community          create         company
# 24            limit        help            nrdc             new
#
#                 4           1
# 0       community     climate
# 1   environmental        year
# 2            nrdc       river
# 3         climate      change
# 4         justice         000
# 5            work        high
# 6            read         amp
# 7             amp      specie
# 8           fight        time
# 9           learn       large
# 10           like     country
# 11         people        food
# 12         farmer      people
# 13          thank    national
# 14         change         end
# 15           year       waste
# 16           need        help
# 17     indigenous      record
# 18           home     protect
# 19           farm   community
# 20          black        life
# 21           live         day
# 22            epa  population
# 23       resident       world
# 24       critical         way

# %% [markdown]
# ### Topic names

# %% [raw]
# NOTE: this step is done by manually looking at the output of the line above...a bit kludgy

# %%
communities = top_terms.columns
modclass_names = ['pollution','climate change','clean energy','drilling rights','community outreach','natural habits']

name_dict = dict(zip(communities, modclass_names))
name_dict
# Out:
# {3: 'pollution',
#  0: 'climate change',
#  6: 'clean energy',
#  2: 'drilling rights',
#  4: 'community outreach',
#  1: 'natural habits'}

# %%
top_terms.columns = modclass_names
top_terms.to_csv('top_terms_by_modclass.csv', index = False)

# %%
top_terms
# Out:
#           pollution climate change    clean energy drilling rights  \
# 0             toxic        climate            fuel             oil
# 1              pfas         change           clean             big
# 2              food       emission          fossil             amp
# 3              safe            new          energy           biden
# 4   foreverchemical         global       pollution         climate
# 5          chemical        warming         climate            land
# 6           product        methane       community  administration
# 7          exposure            gas             air          public
# 8              vote          world        electric           potus
# 9              lead         carbon        industry             gas
# 10              fda          study             new         million
# 11           health           year         vehicle         federal
# 12       california            cut             gas        drilling
# 13          protect         impact          future            stop
# 14              ban           need           power      protection
# 15     californians         report           state           court
# 16              ewg         action             amp         protect
# 17              use           heat             job         billion
# 18            water     greenhouse           plant          profit
# 19            child         reduce            need        industry
# 20          support      scientist            coal            year
# 21            thank       solution             oil            huge
# 22             harm         crisis  infrastructure       president
# 23           family      community          create         company
# 24            limit           help            nrdc             new
#
#    community outreach natural habits
# 0           community        climate
# 1       environmental           year
# 2                nrdc          river
# 3             climate         change
# 4             justice            000
# 5                work           high
# 6                read            amp
# 7                 amp         specie
# 8               fight           time
# 9               learn          large
# 10               like        country
# 11             people           food
# 12             farmer         people
# 13              thank       national
# 14             change            end
# 15               year          waste
# 16               need           help
# 17         indigenous         record
# 18               home        protect
# 19               farm      community
# 20              black           life
# 21               live            day
# 22                epa     population
# 23           resident          world
# 24           critical            way

# %%
adj_list_with_brand_label['topic'] = [name_dict.get(n, n) for n in adj_list_with_brand_label.modularity_class]
# Out:
# /var/folders/0n/jtvl1jfx6hj3j5xbd39_bfp40000gp/T/ipykernel_22736/676405628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adj_list_with_brand_label['topic'] = [name_dict.get(n, n) for n in adj_list_with_brand_label.modularity_class]

# %%
adj_list_with_brand_label.topic.value_counts()
# Out:
# pollution             16293
# climate change        15259
# clean energy          14202
# drilling rights       13847
# community outreach     8817
# natural habits         7410
# Name: topic, dtype: int64

# %%
adj_list_with_brand_label
# Out:
#                         id     Label  brand  modularity_class           topic
# 0      1540683731630927874  increase   @ewg                 0  climate change
# 1      1540683731630927874       new   @ewg                 0  climate change
# 2      1540683731630927874    reduce   @ewg                 0  climate change
# 3      1540683731630927874     study   @ewg                 0  climate change
# 4      1540366146423095296     check   @ewg                 1  natural habits
# ...                    ...       ...    ...               ...             ...
# 85083  1397962840724496386     human  @NRDC                 0  climate change
# 85084  1397962840724496386     learn  @NRDC                 0  climate change
# 85085  1397962839894085633       000  @NRDC                 0  climate change
# 85086  1397962839894085633       new  @NRDC                 0  climate change
# 85087  1397962839894085633     study  @NRDC                 0  climate change
#
# [75828 rows x 5 columns]

# %% [markdown]
# ## Exporting files with top terms appended

# %%
adj_list_with_brand_label.to_csv('adj_list_with_brand_label.csv', index = False)

# %%
data.id = data.id.astype('str')
adj_list_with_brand_label.id = adj_list_with_brand_label.id.astype('str')

data_with_modclass = data.merge(adj_list_with_brand_label[['id', 'topic']], on = 'id', how = 'left')
# Out:
# /Users/alexanderliss/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data.shape
# Out:
# (13619, 7)

# %%
data_with_modclass.drop_duplicates(subset='id', inplace=True)

# %%
data_with_modclass.shape
# Out:
# (13619, 8)

# %%
data_with_modclass.head()
# Out:
#                      id                 created_at  \
# 0   1540683731630927874  2022-06-25 13:10:00+00:00
# 4   1540366146423095296  2022-06-24 16:08:02+00:00
# 8   1540089567218470918  2022-06-23 21:49:00+00:00
# 18  1540063656586756100  2022-06-23 20:06:03+00:00
# 22  1540047792634224642  2022-06-23 19:03:01+00:00
#
#                                                  text brand  polarity_score  \
# 0   A new study in @nature shows that increasing t...  @ewg        0.136364
# 4   No matter how you celebrate, we're wishing you...  @ewg        1.000000
# 8   Farmers and ranchers can take important steps ...  @ewg        0.600000
# 18  A handful of recent FDA decisions allowed seve...  @ewg        0.200000
# 22  Provisions to tackle #PFAS are included in the...  @ewg        0.137500
#
#     subjectivity_score                                     processed_text  \
# 0             0.454545  new study @nature increase sustainability scho...
# 4             1.000000  matter celebrate wish wonderful independence d...
# 8             0.575000  farmer rancher important step lower emission h...
# 18            0.330000  handful recent fda decision allow type phthala...
# 22            0.487500  provision tackle pfa include ndaa fy 2023 repr...
#
#              topic
# 0   climate change
# 4   natural habits
# 8   climate change
# 18       pollution
# 22             NaN

# %%
data_with_modclass.topic.value_counts(normalize=True)
# Out:
# pollution             0.210047
# climate change        0.204938
# clean energy          0.166454
# drilling rights       0.158025
# community outreach    0.134440
# natural habits        0.126096
# Name: topic, dtype: float64

# %% [raw]
# using this var to capture sort order for named topics

# %%
topic_sort_order = data_with_modclass.topic.value_counts().index.values

# %%
data_with_modclass.to_csv('data_with_topic_added.csv', index = False)

# %% [markdown]
# ### Summary of the Topics (e.g. ModClass) by Brand

# %%
adj_list_with_brand_label.pivot_table(index = 'topic', columns = 'brand', aggfunc='size')
# Out:
# brand               @Earthjustice  @EnvDefenseFund  @NRDC  @ewg  @foe_us
# topic
# clean energy                 4009             3572   3485   654     2482
# climate change               2046             6083   2747  1406     2977
# community outreach           2070             1347   2913   818     1669
# drilling rights              4111             1400   2122   453     5761
# natural habits               1683             1758   1242   497     2230
# pollution                    2124              968   2730  9279     1192

# %%
adj_list_with_brand_label.pivot_table(index = 'topic', columns = 'brand', aggfunc='size').reindex(topic_sort_order, columns=author_sort_order).to_csv('author mentions by topic.csv', index = True)

# %%
top_terms_per_segment(top_terms_by_brand_ModClass, 'brand', 25)
# Out:
#      @Earthjustice @EnvDefenseFund          @NRDC             @ewg  \
# 0            biden         climate        climate            toxic
# 1             fuel          change          clean             pfas
# 2              oil        emission         energy             food
# 3            clean           clean      community             safe
# 4   administration             new          water  foreverchemical
# 5           fossil          global  environmental         chemical
# 6        pollution         warming           nrdc          product
# 7           energy          energy           fuel         exposure
# 8          climate         methane        justice             vote
# 9          federal             gas         fossil             lead
# 10   environmental           world            amp              fda
# 11       community          carbon           lead           health
# 12             air        electric         future       california
# 13            land           study          state          protect
# 14        drilling           biden           work              ban
# 15             gas            fuel          biden     californians
# 16      protection            year           read              ewg
# 17        industry         vehicle       drinking              use
# 18           court             cut            job            water
# 19         protect          impact      pollution            child
# 20         justice            need          thank          support
# 21           toxic          report            new            thank
# 22          public          action           need             harm
# 23           river           power         change           family
# 24           power            heat            oil            limit
#
#            @foe_us
# 0              oil
# 1              big
# 2              amp
# 3            biden
# 4          climate
# 5             land
# 6             fuel
# 7           fossil
# 8           public
# 9            potus
# 10             gas
# 11         million
# 12        emission
# 13            year
# 14            stop
# 15             new
# 16          energy
# 17        drilling
# 18         billion
# 19          profit
# 20        industry
# 21  administration
# 22       president
# 23            huge
# 24         company

# %%
top_terms_per_segment(top_terms_by_brand_ModClass, 'brand', 25).reindex(columns=author_sort_order).to_csv('top terms by author.csv', index=True)
